# %%
# !python /kaggle/input/datasets/hunglezzz/fall-detection-training-data/Kaggle_Training/train.py \
    --dataset-source combined \
    --ntu-pkl /kaggle/input/datasets/hunglezzz/fall-detection-training-data/Kaggle_Training/ntu60_hrnet.pkl \
    --custom-train-pkl /kaggle/input/datasets/hunglezzz/fall-detection-training-data/Kaggle_Training/train_data.pkl \
    --custom-val-pkl /kaggle/input/datasets/hunglezzz/fall-detection-training-data/Kaggle_Training/val_data.pkl \
    --output-dir /kaggle/working/runs/fall_detection \
    --sequence-length 30 \
    --epochs 50 \
    --batch-size 128
# Out:
# device: cuda
# dataset source: combined
# fps: 24.0
# fall labels: [1, 2]
# balanced sampler: True
# train samples: 41099
# val samples: 16666
# train labels: [39918, 1181]
# val labels: [16314, 352]
# epoch 001 | train_loss=0.1814 | val_loss=0.0878 | thr=0.80 | precision=0.6700 | recall=0.9403 | fbeta=0.8124
# epoch 002 | train_loss=0.0843 | val_loss=0.0866 | thr=0.80 | precision=0.5269 | recall=0.9744 | fbeta=0.7318
# epoch 003 | train_loss=0.0645 | val_loss=0.0500 | thr=0.80 | precision=0.7222 | recall=0.9602 | fbeta=0.8508
# epoch 004 | train_loss=0.0539 | val_loss=0.0289 | thr=0.76 | precision=0.7965 | recall=0.9119 | fbeta=0.8631
# epoch 005 | train_loss=0.0509 | val_loss=0.0316 | thr=0.79 | precision=0.7990 | recall=0.8920 | fbeta=0.8533
# epoch 006 | train_loss=0.0430 | val_loss=0.0428 | thr=0.80 | precision=0.7244 | recall=0.9261 | fbeta=0.8354
# epoch 007 | train_loss=0.0398 | val_loss=0.0292 | thr=0.76 | precision=0.8005 | recall=0.9006 | fbeta=0.8587
# ...
